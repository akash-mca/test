# %%
import nltk
# nltk.download()

# %%
tokens = []
file_content = open('tweets.txt').readlines()
for line in file_content:
	tokens.append(nltk.word_tokenize(line))

# %%
tokens
# Out:
# [['The',
#   '@',
#   'Tokyo2020',
#   '#',
#   'Playbooks',
#   'and',
#   'COVID-19',
#   'countermeasures',
#   'provide',
#   'the',
#   'framework',
#   'for',
#   'safe',
#   'and',
#   'secure',
#   'Olympic',
#   'Games',
#   '.',
#   'The',
#   'Sport-Specific',
#   'Regulations',
#   'focus',
#   'on',
#   'the',
#   'course',
#   'of',
#   'actions',
#   'to',
#   'minimise',
#   'the',
#   'impact',
#   'on',
#   'the',
#   'athletes',
#   "'",
#   'experience',
#   'and',
#   'avoid',
#   'competition',
#   'delays',
#   '.'],
#  ['The',
#   'IOC',
#   'and',
#   'the',
#   'International',
#   'Paralympic',
#   'Committee',
#   'today',
#   'were',
#   'informed',
#   'by',
#   'the',
#   'Japanese',
#   'parties',
#   'about',
#   'the',
#   'impact',
#   'of',
#   'the',
#   'announcement',
#   'of',
#   'a',
#   'state',
#   'of',
#   'emergency',
#   'in',
#   'Tokyo',
#   'on',
#   'the',
#   'Olympic',
#   'and',
#   'Paralympic',
#   'Games',
#   '.',
# ...
